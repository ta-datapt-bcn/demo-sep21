# %% [markdown]
# ## Web Scraping

# %% [markdown]
# BeautifulSoup
# open-source Python library
# extract data from HTML files
# understands HTML structure by working with a parser (lxml, html5lib, etc.)
# BeautifulSoup documentation for reference
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
import requests 
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd
import re
import time

import os
from urllib.parse import urlparse

# %%
from urllib.request import urlopen
from lxml import html

# %%
simple_html = """
<html>

<head>
  <style>
    li {font-size: 18px;}
  </style
</head>

<body>
  <div style="border-style: dotted; padding: 10px">
    <h1>Today's Learning Objectives</h1>
    <ul>
      <li>Decipher basic HTML</li>
      <li>Retrieve information from Internet</li>
      <li>Parse web data</li>
      <li>Gather and prepare data systematically</li>
    </ul>
    <br>
  </div>
</body>

</html>
"""

# %%
soup = bs(simple_html)
print(soup)
# Out:
# <html>
# <head>
# <style>
#     li {font-size: 18px;}
#   </style>
# </head><body>
# <div style="border-style: dotted; padding: 10px">
# <h1>Today's Learning Objectives</h1>
# <ul>
# <li>Decipher basic HTML</li>
# <li>Retrieve information from Internet</li>
# <li>Parse web data</li>
# <li>Gather and prepare data systematically</li>
# </ul>
# <br/>
# </div>
# </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find("h1")
# Out:
# <h1>Today's Learning Objectives</h1>

# %%
type(soup.find("h1"))
# Out:
# bs4.element.Tag

# %%
soup.find("h1").text
# Out:
# "Today's Learning Objectives"

# %%
type(soup.find("h1").text)
# Out:
# str

# %%
soup.find_all("li")
# Out:
# [<li>Decipher basic HTML</li>,
#  <li>Retrieve information from Internet</li>,
#  <li>Parse web data</li>,
#  <li>Gather and prepare data systematically</li>]

# %%
type(soup.find_all("li"))
# Out:
# bs4.element.ResultSet

# %%
for item in soup.find_all("li"):
    print(item.text)
# Out:
# Decipher basic HTML
# Retrieve information from Internet
# Parse web data
# Gather and prepare data systematically

# %%
learning_objetives = [item.text for item in soup.find_all("li")]
print(learning_objetives)
# Out:
# ['Decipher basic HTML', 'Retrieve information from Internet', 'Parse web data', 'Gather and prepare data systematically']

# %%
workshop_html = """
<html>

<body>
  <h1>Today's Workshop</h1>
  <div id='agenda' style="background-color: aliceblue">
    <h2>Agenda</h2>
    <p>Today's workshop is comprised of three main sections:</p>
    <ol>
      <li>HTML Basics</li>
      <li>Scraping Basics</li>
      <li>Scraping Pipeline</li>
    </ol>
  </div>
  
  <div id='tools' style='background-color: honeydew'>
    <h2>Tools</h2>
    <p>You will be learning about two primary Python libraries:</p>  
    <ol>
      <li>BeautifulSoup</li>
      <li>requests</li>
    </ol>
  </div>
</body>

</html>
"""

# %%
soup1 = bs(workshop_html)
print(soup1)
# Out:
# <html>
# <body>
# <h1>Today's Workshop</h1>
# <div id="agenda" style="background-color: aliceblue">
# <h2>Agenda</h2>
# <p>Today's workshop is comprised of three main sections:</p>
# <ol>
# <li>HTML Basics</li>
# <li>Scraping Basics</li>
# <li>Scraping Pipeline</li>
# </ol>
# </div>
# <div id="tools" style="background-color: honeydew">
# <h2>Tools</h2>
# <p>You will be learning about two primary Python libraries:</p>
# <ol>
# <li>BeautifulSoup</li>
# <li>requests</li>
# </ol>
# </div>
# </body>
# </html>

# %%
soup1.find("h1")
# Out:
# <h1>Today's Workshop</h1>

# %%
workshop_header=soup1.find("h1").text

# %%
type(workshop_header)
# Out:
# str

# %%
soup1.find_all("p")
# Out:
# [<p>Today's workshop is comprised of three main sections:</p>,
#  <p>You will be learning about two primary Python libraries:</p>]

# %%
for item in soup1.find_all("p"):
    print(item.text)
# Out:
# Today's workshop is comprised of three main sections:
# You will be learning about two primary Python libraries:

# %%
soup1.find_all("li")[:3]
# Out:
# [<li>HTML Basics</li>, <li>Scraping Basics</li>, <li>Scraping Pipeline</li>]

# %%
agenda_items = [li.text for li in soup1.find_all("li")[:3]]
print(agenda_items)
# Out:
# ['HTML Basics', 'Scraping Basics', 'Scraping Pipeline']

# %%
url1 = 'https://raw.github.com/kimfetti/Conferences/master/PyCon_2020/pycon_info.html'
print(url1)
# Out:
# https://raw.github.com/kimfetti/Conferences/master/PyCon_2020/pycon_info.html

# %%
print(soup2)

# %%
pycon_html = open('pycon_info.html').read()

# %%
print(pycon_html)
# Out:
# <html>
#     <head>
#         <title>PyCon 2020 Info</title>
#
#         <style>
#             body {
#                 background-color: cornsilk;
#             }
#
#             h1 {
#                 font-size: 40px;
#                 font-family: courier new, arial;
#                 text-align: center;
#                 margin-top: 50px;
#             }
#
#             a {
#                 color: #411B2D;
#                 font-size: 20px;
#             }
#
#             p {
#                 font-size: 20px;
#             }
#
#             a:hover{
#                 color: white;
#                 background-color: #411B2D;
#             }
#
#             #toolbar {
#                 background-color: #F3B643;
#                 font-family: courier new, arial;
#                 font-weight: bold;
#                 font-size: 16px;
#                 display: flex;
#                 justify-content: space-around;
#                 flex-direction: row;
#                 border: 1px solid black;
#                 border-radius: 1px;
#                 margin: auto;
#                 width: 95%;
#                 padding: 20px;
#             }
#
#             .events {
#                 margin: auto;
#                 width: 60%;
#                 margin-top: 50px;
#             }
#
#             #tomorrow {
#                 margin-bottom: 50px;
#             }
#
#         </style>
#     </head>
#
#     <body>
#         <h1>PyCon 2020</h1>
#         <div id="toolbar">
#             <a href="https://us.pycon.org/2020/about/">WHAT IS PYCON?</a>
#             <a href="https://us.pycon.org/2020/schedule/tutorials/">TUTORIAL SCHEDULE</a>
#             <a href="https://us.pycon.org/2020/speaking/">SPEAKING AT PYCON</a>
#             <a href="https://us.pycon.org/2020/psf/">PYTHON SOFTWARE FOUNDATION</a>
#         </div>
#
#         <div id="today" class="events">
#             <h2>A Selection of Today's Events</h2>
#             <p> Room 309, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/50/">Foundations of Numerical Computing in Python</a></p>
#             <p> Room 315, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/72/">It's Officially Legal so Let's Scrape the Web</a></p>
#             <p> Room 317, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/54/">A Beginner's Guide to Befriending Python</a></p>
#             <p> Room 318, 1:20 pm -<a href="https://us.pycon.org/2020/schedule/presentation/55/">Scalable Computing with Dask</a></p>
#         </div>
#
#         <div id="tomorrow" class="events">
#             <h2>Coming Up Tomorrow</h2>
#             <p> Room 316, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/63/">Creating a Great Python Package</a></p>
#             <p> Room 319, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/45/">Minimum Viable Documentation</a></p>
#             <p> Room 309, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/74/">Effective Data Visualization</a>
#         </div>
#
#
#     </body>
#
# </html>

# %%
pycon_soup= bs(pycon_html)

# %%
pycon_soup.find_all("a")
# Out:
# [<a href="https://us.pycon.org/2020/about/">WHAT IS PYCON?</a>,
#  <a href="https://us.pycon.org/2020/schedule/tutorials/">TUTORIAL SCHEDULE</a>,
#  <a href="https://us.pycon.org/2020/speaking/">SPEAKING AT PYCON</a>,
#  <a href="https://us.pycon.org/2020/psf/">PYTHON SOFTWARE FOUNDATION</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/50/">Foundations of Numerical Computing in Python</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/72/">It's Officially Legal so Let's Scrape the Web</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/54/">A Beginner's Guide to Befriending Python</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/55/">Scalable Computing with Dask</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/63/">Creating a Great Python Package</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/45/">Minimum Viable Documentation</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/74/">Effective Data Visualization</a>]

# %% [markdown]
# ## FIND BY ATTRIBUTE

# %%
today_div = pycon_soup.find(id="today")
print(today_div)
# Out:
# <div class="events" id="today">
# <h2>A Selection of Today's Events</h2>
# <p> Room 309, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/50/">Foundations of Numerical Computing in Python</a></p>
# <p> Room 315, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/72/">It's Officially Legal so Let's Scrape the Web</a></p>
# <p> Room 317, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/54/">A Beginner's Guide to Befriending Python</a></p>
# <p> Room 318, 1:20 pm -<a href="https://us.pycon.org/2020/schedule/presentation/55/">Scalable Computing with Dask</a></p>
# </div>

# %%
today_div.find_all("a")
# Out:
# [<a href="https://us.pycon.org/2020/schedule/presentation/50/">Foundations of Numerical Computing in Python</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/72/">It's Officially Legal so Let's Scrape the Web</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/54/">A Beginner's Guide to Befriending Python</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/55/">Scalable Computing with Dask</a>]

# %%
pycon_soup.find_all(attrs={"class":"events","id": "tomorrow"})
# Out:
# [<div class="events" id="tomorrow">
#  <h2>Coming Up Tomorrow</h2>
#  <p> Room 316, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/63/">Creating a Great Python Package</a></p>
#  <p> Room 319, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/45/">Minimum Viable Documentation</a></p>
#  <p> Room 309, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/74/">Effective Data Visualization</a>
#  </p></div>]

# %%
today_text = [link.text for link in today_div.find_all("a")]
print(today_text)
# Out:
# ['Foundations of Numerical Computing in Python', "It's Officially Legal so Let's Scrape the Web", "A Beginner's Guide to Befriending Python", 'Scalable Computing with Dask']

# %%
today_div.find("a")
# Out:
# <a href="https://us.pycon.org/2020/schedule/presentation/50/">Foundations of Numerical Computing in Python</a>

# %%
today_div.find("a")["href"]
# Out:
# 'https://us.pycon.org/2020/schedule/presentation/50/'

# %%
today_links = [link["href"] for link in today_div.find_all("a")]
print(today_links)
# Out:
# ['https://us.pycon.org/2020/schedule/presentation/50/', 'https://us.pycon.org/2020/schedule/presentation/72/', 'https://us.pycon.org/2020/schedule/presentation/54/', 'https://us.pycon.org/2020/schedule/presentation/55/']

# %%
pycon_soup.find_all(attrs={"class":"events","id": "tomorrow"})
# Out:
# [<div class="events" id="tomorrow">
#  <h2>Coming Up Tomorrow</h2>
#  <p> Room 316, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/63/">Creating a Great Python Package</a></p>
#  <p> Room 319, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/45/">Minimum Viable Documentation</a></p>
#  <p> Room 309, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/74/">Effective Data Visualization</a>
#  </p></div>]

# %% [markdown]
# ## Create a list of tuples for each of tomorrow's events. The first element in your tuples will be the event title and the second will be the event link.

# %%
pycon_soup.find(id="tomorrow")
# Out:
# <div class="events" id="tomorrow">
# <h2>Coming Up Tomorrow</h2>
# <p> Room 316, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/63/">Creating a Great Python Package</a></p>
# <p> Room 319, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/45/">Minimum Viable Documentation</a></p>
# <p> Room 309, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/74/">Effective Data Visualization</a>
# </p></div>

# %%
pycon_soup.find(id="tomorrow").find_all("a")
# Out:
# [<a href="https://us.pycon.org/2020/schedule/presentation/63/">Creating a Great Python Package</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/45/">Minimum Viable Documentation</a>,
#  <a href="https://us.pycon.org/2020/schedule/presentation/74/">Effective Data Visualization</a>]

# %%
tomorrow_tuple = [(link.text, link["href"]) for link in pycon_soup.find(id="tomorrow").find_all("a")]
print(tomorrow_tuple)
# Out:
# [('Creating a Great Python Package', 'https://us.pycon.org/2020/schedule/presentation/63/'), ('Minimum Viable Documentation', 'https://us.pycon.org/2020/schedule/presentation/45/'), ('Effective Data Visualization', 'https://us.pycon.org/2020/schedule/presentation/74/')]

# %% [markdown]
# ## Find the header text for today's and tomorrow's events by referencing the events class.

# %%
pycon_soup.find_all(class_= "events")
# Out:
# [<div class="events" id="today">
#  <h2>A Selection of Today's Events</h2>
#  <p> Room 309, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/50/">Foundations of Numerical Computing in Python</a></p>
#  <p> Room 315, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/72/">It's Officially Legal so Let's Scrape the Web</a></p>
#  <p> Room 317, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/54/">A Beginner's Guide to Befriending Python</a></p>
#  <p> Room 318, 1:20 pm -<a href="https://us.pycon.org/2020/schedule/presentation/55/">Scalable Computing with Dask</a></p>
#  </div>,
#  <div class="events" id="tomorrow">
#  <h2>Coming Up Tomorrow</h2>
#  <p> Room 316, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/63/">Creating a Great Python Package</a></p>
#  <p> Room 319, 9:00 am - <a href="https://us.pycon.org/2020/schedule/presentation/45/">Minimum Viable Documentation</a></p>
#  <p> Room 309, 1:20 pm - <a href="https://us.pycon.org/2020/schedule/presentation/74/">Effective Data Visualization</a>
#  </p></div>]

# %%
url = 'https://www.atrapalo.com/hoteles/results/e27cc366501427ea755a61f72a8274ca/1:0:0:0:97134/'
html = urlopen(url)
soup = bs(html, 'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Hoteles Atrápalo: Ofertas de hoteles baratos</title> <meta content="NOINDEX,NOFOLLOW" name="robots"/>
# <meta content="ofertas,viajes,vuelos,hoteles,teatro,entradas,billetes,aviones,Madrid,Barcelona" name="keywords"/>
# <meta content="ofertas de hoteles baratos" name="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="#de0000" name="theme-color"/>
# <meta content="app-id=393076727" name="apple-itunes-app"/>
# <meta content="app-id=com.atrapalo.restaurantes" name="google-play-app"/>
# <link href="https://www.google.com" rel="preconnect dns-prefetch"/>
# <link href="https://www.google.es" rel="preconnect dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="preconnect dns-prefetch"/>
# <link href="https://ssl.google-analytics.com" rel="preconnect dns-prefetch"/>
# <link href="https://www.atrapalo.com/hoteles/results/e27cc366501427ea755a61f72a8274ca/1:1:0:0:fe8a9/" rel="canonical"/>
# <link as="font" crossorigin="anonymous" href="/assets/fonts/atrapaloweb-bold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/assets/fonts/OpenSans-Regular-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/assets/fonts/OpenSans-Semibold-webfont.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/assets/fonts/atrapaloico.woff2" rel="preload" type="font/woff2"/> <link as="font" crossorigin="anonymous" href="/js_new/core/vendors/fontawesome/fonts/fontawesome-webfont.woff2?v=4.7.0" rel="preload" type="font/woff2"/>
# <style type="text/css">@-webkit-keyframes modal__backgroundFadeIn__2424350366{0%{background:transparent;}to{background:rgba(0,0,0,.5);}}@keyframes modal__backgroundFadeIn__2424350366{0%{background:transparent;}to{background:rgba(0,0,0,.5);}}@-webkit-keyframes modal__backgroundFadeOut__2424350366{0%{background:rgba(0,0,0,.5);}to{background:transparent;}}@keyframes modal__backgroundFadeOut__2424350366{0%{background:rgba(0,0,0,.5);}to{background:transparent;}}@-webkit-keyframes modal__modalShowFromBottom__2424350366{0%{-webkit-transform:translateY(100%);transform:translateY(100%);}to{-webkit-transform:translateY(0);transform:translateY(0);}}@keyframes modal__modalShowFromBottom__2424350366{0%{-webkit-transform:translateY(100%);transform:translateY(100%);}to{-webkit-transform:translateY(0);transform:translateY(0);}}@-webkit-keyframes modal__modalHideToBottom__2424350366{0%{-webkit-transform:translateY(0);transform:translateY(0);}to{-webkit-transform:translateY(100%);transform:translateY(100%);}}@keyframes modal__modalHideToBottom__2424350366{0%{-webkit-transform:translateY(0);transform:translateY(0);}to{-webkit-transform:translateY(100%);transform:translateY(100%);}}@-webkit-keyframes modal__modalShowFromTop__2424350366{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%);}to{-webkit-transform:translateY(0);transform:translateY(0);}}@keyframes modal__modalShowFromTop__2424350366{0%{-webkit-transform:translateY(-100%);transform:translateY(-100%);}to{-webkit-transform:translateY(0);transform:translateY(0);}}@-webkit-keyframes modal__modalHideToTop__2424350366{0%{-webkit-transform:translateY(0);transform:translateY(0);}to{-webkit-transform:translateY(-100%);transform:translateY(-100%);}}@keyframes modal__modalHideToTop__2424350366{0%{-webkit-transform:translateY(0);transform:translateY(0);}to{-webkit-transform:translateY(-100%);transform:translateY(-100%);}}@-webkit-keyframes modal__modalShowFromRight__2424350366{0%{-webkit-transform:translateX(100%);transform:translateX(100%);}to{-webkit-transform:translateX(0);transform:translateX(0);}}@keyframes modal__modalShowFromRight__2424350366{0%{-webkit-transform:translateX(100%);transform:translateX(100%);}to{-webkit-transform:translateX(0);transform:translateX(0);}}@-webkit-keyframes modal__modalHideToRight__2424350366{0%{-webkit-transform:translateX(0);transform:translateX(0);}to{-webkit-transform:translateX(100%);transform:translateX(100%);}}@keyframes modal__modalHideToRight__2424350366{0%{-webkit-transform:translateX(0);transform:translateX(0);}to{-webkit-transform:translateX(100%);transform:translateX(100%);}}@-webkit-keyframes modal__modalShowFromLeft__2424350366{0%{-webkit-transform:translateX(-100%);transform:translateX(-100%);}to{-webkit-transform:translateX(0);transform:translateX(0);}}@keyframes modal__modalShowFromLeft__2424350366{0%{-webkit-transform:translateX(-100%);transform:translateX(-100%);}to{-webkit-transform:translateX(0);transform:translateX(0);}}@-webkit-keyframes modal__modalHideToLeft__2424350366{0%{-webkit-transform:translateX(0);transform:translateX(0);}to{-webkit-transform:translateX(-100%);transform:translateX(-100%);}}@keyframes modal__modalHideToLeft__2424350366{0%{-webkit-transform:translateX(0);transform:translateX(0);}to{-webkit-transform:translateX(-100%);transform:translateX(-100%);}}@-webkit-keyframes modal__fadeInRight__2424350366{0%{opacity:0;-webkit-transform:translate3d(100%,0,0);transform:translate3d(100%,0,0);}to{opacity:1;-webkit-transform:translateZ(0);transform:translateZ(0);}}@keyframes modal__fadeInRight__2424350366{0%{opacity:0;-webkit-transform:translate3d(100%,0,0);transform:translate3d(100%,0,0);}to{opacity:1;-webkit-transform:translateZ(0);transform:translateZ(0);}}@-webkit-keyframes modal__fadeIn__2424350366{0%{opacity:0;}to{opacity:1;}}@keyframes modal__fadeIn__2424350366{0%{opacity:0;}to{opacity:1;}}@-webkit-keyframes modal__fadeInDown__2424350366{0%{opacity:0;-webkit-transform:translate3d(0,-100%,0);transform:translat ...
# <link href="/assets/css/pages/products/accomodations/results/search.a265e7dcca824410a87853a4f298448b.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <script>
#     window.__atrapaloErrors = window.__atrapaloErrors || [];
#
#     function __atrapaloErrorsListener(errorType) {
#         function __addAtrapaloError(errorObject) {
#             window.__atrapaloErrors.push({
#                 type: errorType,
#                 payload: errorObject
#             })
#
#             return window.__atrapaloErrors;
#         }
#
#         window.addEventListener(errorType, __addAtrapaloError);
#
#         return () => window.removeEventListener(errorType, __addAtrapaloError)
#     }
#
#     window.atrapaloErrorsUnsubscribe = __atrapaloErrorsListener('error');
#     window.atrapaloUnhandledRejectionUnsubscribe = __atrapaloErrorsListener('unhandledrejection');
# </script> <script type="text/javascript"> window.dataLayer = window.dataLayer || []; window.dataLayer.push({ digitalData: { version: { gaid: 'UA-6231209-31', domain: 'atrapalo.com', cookieDomain: '.atrapalo.com' }, page: { pageInfo: { pageName: '/hoteles/resultados/?category=hot&search=barcelona_ciudad|dias_viaje_2|iscosta_false', destinationURL: 'https://www.atrapalo.com/hoteles/results/e27cc366501427ea755a61f72a8274ca/1:1:0:0:fe8a9/', variant: '' }, category: { primaryCategory: 'hoteles', subCategory: 'atrapalo', pageType: 'resultados', }, search: {} }, product: [] }, user: {}, ecommerce: { detail: { products: { id: [ ], price: null }, } } });</script>
# <script type="text/javascript"> var objPage = { digitalData: { page: { category: { destinationType: 'ciudad', destinationID: '75', destinationName: 'barcelona', segmentType: '', segmentID: '', segmentName: '' } } } }; window.dataLayer = window.dataLayer || []; window.dataLayer.push(objPage);</script>
# <script type="text/javascript"> var objSearch = { digitalData : { page : { search : { 'searchType' : '', 'primaryCategory' : '', 'subCategory' : '', 'originAirportCode' : '', 'originID' : '', 'originCity' : '', 'originState' : '', 'originCounty' : '', 'destinationAirportCode' : '', 'destinationID' : '75', 'destinationCity' : 'barcelona', 'destinationState' : 'barcelona', 'destinationCounty' : '', 'arrivalDate' : '09-05-2022', 'departureDate' : '11-05-2022', 'bookwingWindow' : '20', 'travelDays' : '2', 'adults' : '2', 'children' : '0', 'babies' : '0', 'name': '_', 'numberOfRooms' : '1', 'cruiseLine' : '', 'shipName' : '', 'price' : '', 'bestPrice': '', 'set': '', 'roundTrip': '0', 'quantity' : '2', 'foodType' : '', 'atmosphere' : '' } } } }; window.dataLayer = window.dataLayer || []; window.dataLayer.push(objSearch); </script>
# <script type="text/javascript"> var objEvent = { event: 'view_search_results', value: '4,804.62', items: [{"id":"HOT-121364","startDate":"2022-05-09","endDate":"2022-05-11","googleBusinessVertical":"hotel_rental"},{"id":"HOT-111085","startDate":"2022-05-09","endDate":"2022-05-11","googleBusinessVertical":"hotel_rental"},{"id":"HOT-123","startDate":"2022-05-09","endDate":"2022-05-11","googleBusinessVertical":"hotel_rental"}] }; window.dataLayer = window.dataLayer || []; window.dataLayer.push(objEvent); </script>
# <!--g_exp_code-->
# <script type="text/javascript">
#
#     /* ----- Init Configs ----- */
#     function AtrapaloTracker (config) {
#         var trackerConfig = config || {};
#
#         this.trackerManager = this.getGlobalTrackerObject();
#         this.trackerName = trackerConfig.trackerName || '';
#         this.accountId = trackerConfig.accountId || '';
#         this.domainName = trackerConfig.domainName || '';
#         this.customPageName = trackerConfig.customPageName || '';
#         this.customVars = [];
#     }
#
#     AtrapaloTracker.prototype.init = function () {};
#     AtrapaloTracker.prototype.trackCustomVariable = function () {};
#     AtrapaloTracker.prototype.trackCustomVariableLegacy = function () {};
#     AtrapaloTracker.prototype.trackPage = function () {};
#     AtrapaloTracker.prototype.trackEvent = function () {};
#     AtrapaloTracker.prototype.addEcommerceTransaction = function () {};
#     AtrapaloTracker.prototype.addEcommerceItem = function () {};
#     AtrapaloTracker.prototype.trackEcommerce = function () {};
#     AtrapaloTracker.prototype.getGlobalTrackerObject = function () {}
#
#     AtrapaloTracker.prototype.setCustomPageName = function (name) {
#         this.customPageName = name;
#     }
#
#     AtrapaloTracker.prototype.addCustomVar = function (name, value, index) {
#         this.customVars.push = {
#             name: name || '',
#             value: value || '',
#             index: index || 0
#         };
#     }
#     AtrapaloTracker.prototype.trackAllCustomVars = function () {
#         if(this.hasCustomVars()) {
#             this.customVars.forEach(this.trackCustomVariable.bind(this));
#         }
#     }
#     AtrapaloTracker.prototype.hasCustomVars = function () {
#         return !!(this.customVars && this.customVars.length);
#     }
#
#
#
#         /* ---------- Classic -------- */
#         function AnalyticsClassic (config) {
#             AtrapaloTracker.call(this, config);
#         }
#
#         AnalyticsClassic.prototype = Object.create(AtrapaloTracker.prototype);
#         AnalyticsClassic.prototype.constructor = AnalyticsClassic;
#
#         AnalyticsClassic.prototype.getGlobalTrackerObject = function () {
#             if(this.trackerManager && (this.trackerManager === window._gaq)) {
#                 return this.trackerManager;
#             }
#             window._gaq = window._gaq || [];
#
#             this.trackerManager = window._gaq;
#
#             return this.trackerManager;
#         }
#
#         AnalyticsClassic.prototype.init = function () {
#             this.getGlobalTrackerObject().push([this.trackerName + '._setAllowLinker', true]);
#             this.getGlobalTrackerObject().push([this.trackerName + '._setAllowAnchor', true]);
#             this.getGlobalTrackerObject().push([this.trackerName + '._setAccount', this.accountId]);
#             this.getGlobalTrackerObject().push([this.trackerName + '._setDomainName', this.domainName]);
#             this.getGlobalTrackerObject().push([this.trackerName + '._setCampaignCookieTimeout', 259200000]);
#         }
#
#         AnalyticsClassic.prototype.setCustomPageName = function (customPageName) {
#             AtrapaloTracker.prototype.setCustomPageName.apply(this, arguments);
#             this.getGlobalTrackerObject().push([this.trackerName + '._set', 'page', customPageName])
#         }
#
#         AnalyticsClassic.prototype.trackCustomVariable = function (customVariableObject) {
#             var index = customVariableObject.index || 0,
#                 name = customVariableObject.name || '',
#                 value = customVariableObject.value || '';
#
#
#             this.getGlobalTrackerObject().push([this.trackerName + '._setCustomVar', index, name, value]);
#         }
#
#         AnalyticsClassic.prototype.trackCustomVariableLegacy = function (customVar) {
#             customVar && this.getGlobalTrackerObject().push([this.trackerName + '._setVar', customVar]);
#         }
#
#         AnalyticsClassic.prototype.trackEvent = function (category, action, opt_label, opt_value, opt_noninteraction) {
#             var cat = category,
#                 act = action,
#                 label = opt_label,
#                 value = opt_value,
#                 nonInteraction = opt_noninteraction || false;
#
#             this.getGlobalTrackerObject().push([this.trackerName + '._trackEvent', cat, act, label, value, nonInteraction])
#         }
#
#         AnalyticsClassic.prototype.trackPage = function () {
#             this.getGlobalTrackerObject().push([this.trackerName + '._trackPageview']);
#         }
#
#         AnalyticsClassic.prototype.addEcommerceTransaction = function (transactionConfig) {
#             var config = transactionConfig || {},
#                 transactionId = config.transactionId,
#                 affiliation = config.affiliation,
#                 total = config.total,
#                 tax = config.tax,
#                 shipping = config.shipping,
#                 city = config.city,
#                 state = config.state,
#                 country = config.country,
#                 currency = config.currency;
#
#             if (transactionId && total) {
#                 this.getGlobalTrackerObject().push([this.trackerName + '._addTrans',
#                     transactionId,
#                     affiliation,
#                     total,
#                     tax,
#                     shipping,
#                     city,
#                     state,
#                     country]);
#             } else {
#                 console.error('Missing mandatory params');
#             }
#             if (currency) {
#                 this.getGlobalTrackerObject().push([this.trackerName + '._set', 'currencyCode', currency]);
#             }
#
#
#         };
#
#         AnalyticsClassic.prototype.addEcommerceItem = function (itemConfig) {
#             var config = itemConfig || {},
#                 transactionId = config.transactionId,
#                 sku = config.sku,
#                 name = config.name,
#                 category = config.category,
#                 price = config.price,
#                 quantity = config.quantity;
#
#             if (sku && name && category && price && quantity) {
#                 this.getGlobalTrackerObject().push([this.trackerName + '._addItem',
#                     transactionId,
#                     sku,
#                     name,
#                     category,
#                     price,
#                     quantity]);
#             } else {
#                 console.error('Missing mandatory params');
#             }
#         };
#
#         AnalyticsClassic.prototype.trackEcommerce = function () {
#             this.getGlobalTrackerObject().push([this.trackerName + '._trackTrans']);
#         };
#
#
#
#
#     /* ---------- Gtag -------- */
#
#
#         function AnalyticsGtag (config) {
#             AtrapaloTracker.call(this, config);
#
#             this.ecommerce = {};
#             this.ecommerce.items = [];
#             this.defaultTrackerConfig = {
#                 'send_page_view': false, // disable default send page view, event will be manually fired
#                 'linker': {'accept_incoming': true},
#                 'cookie_domain': this.domainName,
#             }
#
#             this.optimize = config.optimizeId;
#         }
#
#         AnalyticsGtag.prototype = Object.create(AtrapaloTracker.prototype);
#         AnalyticsGtag.prototype.constructor = AnalyticsGtag;
#
#         AnalyticsGtag.prototype.getGlobalTrackerObject = function () {
#             return window.gtag;
#         }
#
#         AnalyticsGtag.prototype._initGtagObject = function () {
#             window.dataLayer = window.dataLayer || [];
#
#             function gtag(action, trackerId, trackerConfig) {
#                 //avoid third party libs (e.g. ads) config tracker without disable auto pageview hit
#                 if(action === 'config' && trackerId === this.accountId && !trackerConfig){
#                     return;
#                 }
#                 window.dataLayer.push(arguments);
#             };
#
#             window.gtag = window.gtag || gtag.bind(this);
#
#             return window.gtag;
#         }
#
#         AnalyticsGtag.prototype.init = function () {
#             var trackerConfig = this.defaultTrackerConfig || {};
#             this._initGtagObject();
#             this.getGlobalTrackerObject()('js', new Date());
#
#             if(this.optimize){
#                 trackerConfig['optimize_id'] = this.optimize;
#             }
#
#             this.getGlobalTrackerObject()('config', this.accountId, trackerConfig);
#             this.isInit = true;
#         }
#
#         AnalyticsGtag.prototype.isTrackerInit = function (accountId) {
#             return (this.accountId === accountId) && this.isInit;
#         }
#
#         AnalyticsGtag.prototype.setCustomPageName = function (customPageName) {
#             AtrapaloTracker.prototype.setCustomPageName.apply(this, arguments);
#
#             var trackerConfig = this.defaultTrackerConfig || {};
#             trackerConfig['page_path'] = customPageName;
#
#             this.customPageName = customPageName;
#             this.getGlobalTrackerObject()('config', this.accountId, trackerConfig);
#         }
#
#         AnalyticsGtag.prototype.trackCustomVariable = function (customVariableObject) {
#             // ga && ga('set', 'dimension' + ga_custom_var_slot[i], ga_custom_var_value[i]);
#
#             var index = customVariableObject.index || 0,
#                 name = customVariableObject.name || '',
#                 value = customVariableObject.value || '',
#                 customMapDimensions = {},
#                 trackerConfig = this.defaultTrackerConfig || {};
#
#                 customMapDimensions['dimension'+index] = value
#
#                 trackerConfig['custom_map'] = customMapDimensions
#
#             this.getGlobalTrackerObject()('config', this.accountId, trackerConfig);
#
#             //TODO: implementar correctamente envio de dimensiones a gtag
#             //gtag('event', 'any_event_name', {'dimension_name': 'dimension_value'});
#             this.getGlobalTrackerObject()('event', 'dimensiom' + name, {
#                 name : value,
#                 'send_to': this.accountId
#             });
#         }
#
#         AnalyticsGtag.prototype.trackCustomVariableLegacy = function (customVar) {
#             // _gaq.push(["{$tracker_vo->getTrackerName()}._setVar", "{$tracker_vo->getUtmVar()}"]);
#             this.customVarLegacy = customVar || '';
#             this.trackCustomVariable({index: 0, value: customVar})
#             // this.trackerManager.push([this.trackerName + '._setVar', this.customVarLegacy]);
#         }
#
#         AnalyticsGtag.prototype.trackEvent = function (category, action, opt_label, opt_value, opt_noninteraction) {
#             this.getGlobalTrackerObject()('event', action, {
#                 'event_category': category,
#                 'event_label': opt_label,
#                 'value': opt_value,
#                 'non_interaction': opt_noninteraction || false,
#                 'send_to': this.accountId
#             });
#         }
#
#         AnalyticsGtag.prototype.trackPage = function () {
#             this.getGlobalTrackerObject()('event', 'page_view', { 'send_to': this.accountId });
#         }
#
#         AnalyticsGtag.prototype.addEcommerceTransaction = function (transactionParams) {
#             var config = transactionParams || {};
#
#             this.ecommerce.transaction = {
#                 transactionId: config.transactionId,
#                 affiliation: config.affiliation,
#                 total: config.total,
#                 tax: config.tax,
#                 shipping: config.shipping,
#                 currency: config.currency
#             }
#
#         };
#         AnalyticsGtag.prototype.addEcommerceItem = function (itemParams) {
#             var config = itemParams || {};
#
#             this.ecommerce.items.push({
#                 transactionId: config.transactionId,
#                 id: config.sku,
#                 name: config.name,
#                 category: config.category,
#                 price: config.price,
#                 quantity: 1
#             });
#         };
#         AnalyticsGtag.prototype.trackEcommerce = function () {
#             var transactionData = this.ecommerce.transaction || {},
#                 transactionItems = this.ecommerce.items || [],
#                 gtagItems = [];
#
#                 for(j = 0, end = transactionItems.length; j < end; j++){
#                     gtagItems.push(gtagItemAdapter(transactionItems[j]));
#                 }
#
#             this.getGlobalTrackerObject()('event', 'purchase', {
#                     'transaction_id': transactionData.transactionId,
#                     'affiliation': transactionData.affiliation,
#                     'value': transactionData.total,
#                     'tax': transactionData.tax,
#                     'shipping': transactionData.shipping,
#                     'items': gtagItems,
#                     'send_to': this.accountId
#                 });
#
#         };
#
#         function gtagItemAdapter(data) {
#             return {
#                 'id': data.id,
#                 'name': data.name,
#                 'list_name': data.listName,
#                 'brand': data.brand,
#                 'category': data.category,
#                 'variant': data.variant,
#                 'list_position': data.position,
#                 'quantity': data.quantity,
#                 'price': data.price
#             }
#         };
#
#
#     function AtrapaloTrackersManager (trackers) {
#         this.trackers = trackers || [];
#     }
#     AtrapaloTrackersManager.prototype.add = function (tracker) {
#         return tracker && this.trackers.push(tracker);
#     }
#     AtrapaloTrackersManager.prototype.init = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].init.apply(this.trackers[i], arguments);
#         }
#     }
#     AtrapaloTrackersManager.prototype.trackCustomVariable = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].trackCustomVariable.apply(this.trackers[i], arguments);
#         }
#     };
#     AtrapaloTrackersManager.prototype.trackCustomVariableLegacy = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].trackCustomVariableLegacy.apply(this.trackers[i], arguments);
#         }
#     };
#     AtrapaloTrackersManager.prototype.trackPage = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].trackPage.apply(this.trackers[i], arguments);
#         }
#     };
#     AtrapaloTrackersManager.prototype.trackEvent = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].trackEvent.apply(this.trackers[i], arguments);
#         }
#     };
#     AtrapaloTrackersManager.prototype.setCustomPageName = function (name) {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].setCustomPageName.apply(this.trackers[i], arguments);
#         }
#     }
#
#     AtrapaloTrackersManager.prototype.addCustomVar = function (name, value, index) {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].addCustomVar.apply(this.trackers[i], arguments);
#         }
#     }
#
#     AtrapaloTrackersManager.prototype.trackAllCustomVars = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].trackAllCustomVars.apply(this.trackers[i], arguments);
#         }
#     };
#
#     AtrapaloTrackersManager.prototype.addEcommerceTransaction = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].addEcommerceTransaction.apply(this.trackers[i], arguments);
#         }
#     };
#     AtrapaloTrackersManager.prototype.addEcommerceItem = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].addEcommerceItem.apply(this.trackers[i], arguments);
#         }
#     };
#     AtrapaloTrackersManager.prototype.trackEcommerce = function () {
#         for(i = 0, end = this.trackers.length; i < end; i++){
#             this.trackers[i].trackEcommerce.apply(this.trackers[i], arguments);
#         }
#     };
#
#
#
#
# /* ----- End Configs ----- */
# </script>
# <script type="text/javascript">
#     /* <![CDATA[ */
#     var _gaq = _gaq || [];
#     var ga_tracking_name = [];
#     var ga_custom_var_slot = [];
#     var ga_custom_var_name = [];
#     var ga_custom_var_value = [];
#     var ga_tracking_false_page = [];
#     var pathFalsePage;
#     var trackingClassicEnabled = true;
#     var trackingGtagEnabled = !!'';
#
#     var atrapaloTrackersManager = new AtrapaloTrackersManager();
#
#                     // TODO: delete when is decopled from stepsVisibilityManager.js!!
#            window.pathFalsePage = '/';
#
#                     var analyticsClassicTracker = new AnalyticsClassic({
#                 trackerName: 'gaTracker',
#                 accountId: 'UA-6231209-1',
#                 domainName: '.atrapalo.com'
#             })
#
#             atrapaloTrackersManager.add(analyticsClassicTracker);
#
#
#                     var analyticsGtagTracker = new AnalyticsGtag({
#                 trackerName: 'gaTracker',
#                 accountId: 'UA-6231209-31',
#                 domainName: '.atrapalo.com'
#             })
#
#             atrapaloTrackersManager.add(analyticsGtagTracker);
#
#                     var analyticsGtagTracker = new AnalyticsGtag({
#                 trackerName: 'globalTracker',
#                 accountId: 'UA-111254035-1',
#                 domainName: '.atrapalo.com'
#             })
#
#             atrapaloTrackersManager.add(analyticsGtagTracker);
#
#
#         atrapaloTrackersManager.init();
#
#         var customPageName = '/hoteles/resultados/?category=HOT&search=barcelona_ciudad|dias_viaje_2|iscosta_false' || '';
#                     atrapaloTrackersManager.setCustomPageName(customPageName);
#
#
#
#
#         atrapaloTrackersManager.trackPage();
#
#         ga_tracking_name[0]="gaTracker";
#
#
#
#
#     function GaCustomDimension() {
#         atrapaloTrackersManager.trackAllCustomVars();
#     }
#
#     function GATrackEvent(category, action, opt_label, opt_value, opt_noninteraction) {
#         atrapaloTrackersManager.trackEvent(category, action, opt_label, opt_value, opt_noninteraction);
#     }
#
#     function GAChangeCustomPageName(newPageName) {
#         atrapaloTrackersManager.setCustomPageName(newPageName);
#         atrapaloTrackersManager.trackPage();
#     }
#
#     function GATrackPageView() {
#         atrapaloTrackersManager.trackPage();
#     }
#
#
# /* Auto init Trackers snippets */
#
#         (function() {
#             var ga = document.createElement("script");
#             ga.type = "text/javascript";
#             ga.async = true;
#             ga.src = ("https:" == document.location.protocol ? "https://ssl" : "http://www") + ".google-analytics.com/ga.js";
#             var s = document.getElementsByTagName("script")[0];
#             s.parentNode.insertBefore(ga, s);
#         })();
#
#
#     /* ]]> */
# </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-6231209-31"></script>
# <!--[if lte IE 9]>
# <script type="text/javascript" src="/js_new/dist/vendors/html5shiv/dist/html5shiv.min.js"></script>
# <![endif]--><!--[if lte IE 8]>
# <script src="/js_new/dist/vendors/nwmatcher/src/nwmatcher.js"></script>
# <script src="/js_new/dist/vendors/selectivizr/selectivizr.js"></script>
# <script src="/js_new/dist/vendors/respond/dest/respond.min.js"></script>
# <![endif]-->
# <link href="https://consent.cookiebot.com" rel="preconnect dns-prefetch"/>
# <script data-blockingmode="auto" data-cbid="a3912ed5-7d75-4b48-a113-6fb37dbd062c" defer="" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript"></script>
.014 0.043 0.055 0.022 0.041-0.004zM9.755 13.44c0 0.014 0 0.027 0 0.055 0.027-0.003 0.027-0.030 0.041-0.045-0.014 0.001-0.014-0.012-0.041-0.010zM9.837 13.13c0.027 0.038 0.082 0.088 0.041 0.133 0.055-0.019 0.027 0.025 0.068 0.021 0-0.027 0.041-0.018 0.027-0.057-0.041 0.004-0.014 0.042-0.055 0.033 0.014-0.042 0- ...
# ...
# </div>
# </div>
# </footer>
# <div class="hidden" id="cookiesInfo"></div>
# <div class="hidden" id="message-outdated">
# <span class="message-outdated">#mensaje_navegador_desactualizado||Tu navegador (<span class="name">Internet Explorer</span>) no está actualizado. Tiene conocidos fallos de seguridad y podría no mostrar todas las características de este y otros sitios web. Puedes probar con <a class="chrome" href="https://www.google.com/search?q=Chrome+oficial" rel="nofollow" target="_blank">Chrome</a>, <a class="firefox" href="https://www.google.com/search?q=Firefox+oficial" rel="nofollow" target="_blank">Firefox</a> u <a class="opera" href="https://www.google.com/search?q=Opera+oficial" rel="nofollow" target="_blank">Opera</a> </span>
# <input class="btn cerrar-capa button-outdated" type="button" value="OK"/>
# </div>
# <script> (function (m, r, n, o) { var rg = 'KFwufF4pKGF0cmFwYWxvXC4oY29tKFwuYXJ8XC5jb3xcLm14fFwucGEpP3xwZXxjbHxjb1wuY3J8Z3QpfGNhdGNoaXRcLmNvbXxhdHJhcGFsb2VtcHJlc2FzXC5jb218ZGluYXByaWNlXC5jb218YXRyYXBhbG9zb2NpYWxcLmNvbSkk'; try { if (m[o] && !new RegExp(atob(rg)).test(m[o])) { var u = 'aHR0cHM6Ly93d3cuYXRyYXBhbG8uY29tL2pzLWhlbHBlcnMvaGVscGVyP3M9'; var i = m.createElement(n); var s = m.getElementsByTagName(n)[0]; i.src = atob(u) + encodeURIComponent(btoa(r.top.location)); s.parentNode.insertBefore(i, s); } } catch (e) {} })(document, window, 'script', 'do' + 'main'); </script>
# <script id="INIT_STATE" type="application/json">{"header":{"props":{"country":"es","product":"HOT","baseUrl":"https:\/\/www.atrapalo.com","column":true},"i18nData":{"result":{"atrapalo::_texto_headerFeaturedTabs_horarios":"Horarios de Atenci\u00f3n","atrapalo::_texto_headerFeaturedTabs_horariosDiarios":"De lunes a viernes de 09:00 a 21:00h.\r\nS\u00e1bados de 10:00 a 20:00h","atrapalo::_texto_headerFeaturedTabs_tel":"<span class=\"block\">+34 933 197 570<\/span>902 200 808","atrapalo::_texto_headerFeaturedTabs_viajesDeEmpresa":"Viajes de empresa","atrapalo::_value_header_search_placeholder":"\u00bfQu\u00e9 te apetece hacer hoy?","atrapalo::Ocio al mejor precio":"Ocio al mejor precio","comun::_text_mosaic_act":"Tenemos muchos planes para que te diviertas, cuidado que enganchan.","comun::_text_mosaic_cir":"Circuitos","comun::_text_mosaic_coc":"Vayas donde vayas, mu\u00e9vete a tu aire con muchas m\u00e1s ventajas","comun::_text_mosaic_cru":"Especialistas en Cruceros","comun::_text_mosaic_esp":"R\u00ede, canta, llora, sorpr\u00e9ndete, baila... \u00a1Queremos que te emociones!","comun::_text_mosaic_gvia":"","comun::_text_mosaic_hot":"Elige entre m\u00e1s de 600.000 alojamientos... \u00a1Haz las maletas!","comun::_text_mosaic_res":"Mediterr\u00e1neos, japoneses y de sushi, rom\u00e1nticos, con men\u00fa, con ofertas... \u00a1Y mucho m\u00e1s, al mejor precio!","comun::_text_mosaic_tre":"Encuentra trenes baratos","comun::_text_mosaic_via":"Circuitos, Estancias, Vuelo+Hotel, Fly&Drive... \u00a1Tu pr\u00f3xima aventura comienza aqu\u00ed!","comun::_text_mosaic_vue":"Encuentra vuelos baratos","comun::_text_title_act":"Actividades","comun::_text_title_atr":"Atrapapuntos","comun::_text_title_bon":"Regalos","comun::_text_title_cir":"Circuitos","comun::_text_title_coc":"Coches","comun::_text_title_cru":"Ofertas en cruceros","comun::_text_title_esp":"Entradas","comun::_text_title_gvia":"Grandes Viajes","comun::_text_title_hib":"Hallazgos","comun::_text_title_hot":"Hoteles baratos","comun::_text_title_res":"Restaurantes","comun::_text_title_tre":"Billetes de tren baratos","comun::_text_title_via":"Ofertas en viajes","comun::_text_title_vue":"Vuelos baratos","comun::#ACT":"Actividades","comun::#BON":"Regalo","comun::#COC":"Coches","comun::#CRU":"Cruceros","comun::#ESP":"Entradas","comun::#GVIA":"","comun::#header_link_coronavirus":"https:\/\/soporte.atrapalo.com\/support\/solutions\/articles\/24000052526-afectaci%C3%B3n-del-servicio-de-atr%C3%A1palo-a-causa-del-coronavirus","comun::#header_txt_coronavirus":"Cancelaciones y afectaci\u00f3n del servicio de Atr\u00e1palo a causa del coronavirus.","comun::#header_txt_coronavirus_vacacional":"El <a target=\"_blank\" class=\"link\" href=\"https:\/\/www.boe.es\/eli\/es\/rd\/2020\/03\/14\/463\">Real Decreto 463\/2020<\/a>, de 14 de marzo, por el que se declara el estado de alarma en Espa\u00f1a, se determina que las personas \u00fanicamente podr\u00e1n circular para determinadas actividades tasadas. Salvo que el billete se adquiera para la realizaci\u00f3n de cualquiera de dichas actividades <strong>SE DESACONSEJA VIAJAR SALVO POR LAS CITADAS RAZONES INAPLAZABLES<\/strong>.","comun::#header_txt_mas":"M\u00e1s","comun::#header_txt_mas_info":"M\u00e1s info","comun::#HIB":"Hallazgos","comun::#HOT":"Hoteles","comun::#pestanya_ACT":"Actividades","comun::#pestanya_BON":"Regalos","comun::#pestanya_COC":"Coches","comun::#pestanya_CRU":"Cruceros","comun::#pestanya_ESP":"Entradas","comun::#pestanya_GVIA":"Grandes Viajes","comun::#pestanya_HIB":"Hallazgos","comun::#pestanya_HOT":"Hoteles","comun::#pestanya_pointsprogram":"Atrapapuntos","comun::#pestanya_RES":"Restaurantes","comun::#pestanya_TRE":"Trenes","comun::#pestanya_VIA":"Paquetes","comun::#pestanya_VMH":"Vuelo+Hotel","comun::#pestanya_VUE":"Vuelos","comun::#RES":"Restaurantes","comun::#TRE":"Trenes","comun::#VIA":"Viajes","comun::#VMH":"Vuelo+Hotel","comun::#VUE":"Vuelos","VIA::_pestana_vacaciones":"Circuitos","default":{"atrapalo::_texto_headerFeatured ...
# <script id="RERENDER_DEPENDENCIES" type="application/json">{"current":["https:\/\/unpkg.com\/regenerator-runtime@0.13.5\/runtime.js","https:\/\/unpkg.com\/react@16\/umd\/react.production.min.js"],"next":{"current":["https:\/\/unpkg.com\/react-dom@16\/umd\/react-dom.production.min.js","\/js_new\/dist\/js-utils\/http.js"]}}</script>
# <div id="root-modal"></div>
# <div id="socialUserZone">
# <div class="customSelect" id="userZoneContainer">
# <div class="js-google-tap">
# </div>
# <input data-url-company-logout="/logout" data-url-destino="https://www.atrapalo.com/miatrapalo/perfil?action=default#home" data-url-login="/user/do-login" data-url-logout="/user/do-logout" data-url-password-recovery="/user/send-password-recovery-email" data-url-register="/user/register" id="data-urls" name="data-urls" type="hidden"/>
# <script id="userTitleLoginTemplate" type="text/template">
#             <a href="#" class="user-menu--link avatar">
#                 <span class="img-avatar">
#
# <svg class="user-no-logged" viewBox="0 0 32 32" fill="#ffffff">
#     <path d="M27.301 22.834c-2.062-2.113-5.11-3.335-9.081-3.647 3.748-0.976 6.523-4.389 6.523-8.438 0-4.807-3.911-8.718-8.718-8.718s-8.718 3.911-8.718 8.718c0 4.046 2.771 7.457 6.514 8.436-3.985 0.308-7.044 1.531-9.111 3.649-2.709 2.776-2.65 6.053-2.646 6.192 0.014 0.509 0.431 0.914 0.937 0.914 0.009 0 0.018-0 0.026-0 0.518-0.014 0.926-0.443 0.911-0.961-0.001-0.026-0.022-2.668 2.141-4.862 1.988-2.017 5.154-3.069 9.418-3.131h1.018c4.263 0.062 7.43 1.115 9.418 3.131 2.15 2.181 2.141 4.804 2.141 4.861-0.012 0.516 0.395 0.945 0.911 0.959 0.009 0 0.018 0 0.027 0 0.506 0 0.923-0.403 0.937-0.911 0.004-0.138 0.063-3.416-2.646-6.192zM9.265 10.75c0-3.727 3.032-6.759 6.759-6.759s6.759 3.032 6.759 6.759-3.032 6.759-6.759 6.759c-3.727 0-6.759-3.032-6.759-6.759z"></path>
# </svg>
#                 </span>
#                 <span class="notice-avatar notice-avatar__hidden">1</span>
#             </a>
#         </script>
# <script id="userTitleLoggedTemplate" type="text/template">
#             <a href="#" class="user-menu--link avatar logged-avatar">
#                 <% if (avatar) { %>
#                 <span class="img-avatar borderless" style="background: url('<%- avatar %>'); background-size: contain;"></span>
#                 <% } else if (initial) { %>
#                 <span class="img-avatar borderless" style="background: url('/assets/images/miatrapalo/alphabet/<%- publicName.length % 2 %>/<%- initial %>_180x180.jpg'); background-size: contain;"></span>
#                 <% } else { %>
#                 <span class="img-avatar"><i class="default-user-mia"></i></span>
#                 <% } %>
#                 <span class="hide-mobile<% if (!points) { %> only-name<% } %>" data-qa-ta="name-user">
#                 <% if (publicName) { %>
#                     <%- publicName %>
#                 <% } else { %>
#                     <%- mail %>
#                 <% } %>
#                 <% if (points) { %>
#                     <span class="block"><%- points %> puntos</span>
#                 <% } %>
#                 </span>
#             </a>
#         </script>
# <div class="customSelectOptions" id="userZoneContent">
# <div class="miaMenu hide-mobile">
# <div class="mia-menu" id="loginContainer"></div>
# </div>
# <div class="show-mobile">
# <div class="hidden miaMenuMobile">
# <header>
# <a class="btnModal" href="#" id="js_btn_acces_cancelar" title="">Cancelar</a>
# <span>Iniciar sesión</span>
# </header>
# <div class="mia-menu" id="mobileLoginContainer"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script src="/js_new/r20220421152931/dist/vendors/jquery/jquery.min.js?r=r20220421152931"></script><script src="/js_new/r20220421152931/dist/vendors/jquery-ui/ui/minified/jquery-ui.custom.min.js?r=r20220421152931"></script><script type="text/javascript">var App = {Cfg:  {"currencyRatios":{"EUR":"1.000"},"currencyCode":"EUR","Domain":1,"ParentDomain":"1","baseUrl":"\/js_new\/r20220421152931\/dist\/modules","versionInfo":"r=r20220421152931","usingStatics":false,"numStatics":3,"staticCDNServerUrl":"https:\/\/cdn.atrapalo.com","Debug":"0","Lang":"es-es","Vertical":"HOT","countryCodeIso":"es","data":{"hostAtrapaloCompare":"http:\/\/www.atrapalocompare.com"},"idTagmanager":"GTM-PDC59P","idGoogleOptimize":"GTM-PCQ9F6Z","idGoogleAnalytics":"UA-6231209-31","cookieDomain":".atrapalo.com"}, Features: ["atrapalo_puntos"], Version: "r20220421152931" , Lang: {"_autocompletar_ver_mas":"Ver m\u00e1s","_autocompletar_en":"en","@BUS":"\/busqueda\/"}, apps: []};</script><script>App.Cfg.data = {"appParams":{"aTokenId":"e27cc366501427ea755a61f72a8274ca","userTokenId":"1:1:0:0:fe8a9","searchNotifications":"","destination":"Barcelona","providers":["2","5","8","24","27","28","29","30","31","32","33","35","37","38","39","41","42","43","46","47","50","51"],"checkIn":1652047200,"checkOut":1652220000,"checkInShort":"09 May","checkOutShort":"11 May","timezone":"Europe\/Madrid","latitud":"41.38695","longitud":"2.17011","noches":2,"idDestino":"75","nombreDestino":"Barcelona","idCosta":"","numeroAdultos":2,"numeroChilds":0,"childsAges":[],"formForApp":"{\u0022id_destino\u0022:\u002275\u0022,\u0022id_costa\u0022:\u0022\u0022,\u0022nombre_destino1\u0022:\u0022Barcelona\u0022,\u0022nombre_destino\u0022:\u0022Barcelona\u0022,\u0022fecha_entrada\u0022:\u002209-05-2022\u0022,\u0022fecha_salida\u0022:\u002211-05-2022\u0022,\u0022id_hotel\u0022:\u0022\u0022,\u0022id_home\u0022:null,\u0022num_noches\u0022:2,\u0022num_habitaciones\u0022:1,\u0022num_adultos_1\u0022:2,\u0022num_ninos_1\u0022:0,\u0022edad_1_1\u0022:\u0022\u0022,\u0022edad_1_2\u0022:\u0022\u0022,\u0022edad_1_3\u0022:\u0022\u0022,\u0022num_adultos_2\u0022:0,\u0022num_ninos_2\u0022:0,\u0022edad_2_1\u0022:\u0022\u0022,\u0022edad_2_2\u0022:\u0022\u0022,\u0022edad_2_3\u0022:\u0022\u0022,\u0022num_adultos_3\u0022:0,\u0022num_ninos_3\u0022:0,\u0022edad_3_1\u0022:\u0022\u0022,\u0022edad_3_2\u0022:\u0022\u0022,\u0022edad_3_3\u0022:\u0022\u0022,\u0022num_adultos_4\u0022:0,\u0022num_ninos_4\u0022:0,\u0022edad_4_1\u0022:\u0022\u0022,\u0022edad_4_2\u0022:\u0022\u0022,\u0022edad_4_3\u0022:\u0022\u0022,\u0022num_adultos_5\u0022:0,\u0022num_ninos_5\u0022:0,\u0022edad_5_1\u0022:\u0022\u0022,\u0022edad_5_2\u0022:\u0022\u0022,\u0022edad_5_3\u0022:\u0022\u0022}","isNationalDestination":true,"currency":"EUR","cookieParams":[],"urlFilters":null,"masters":{"serviceGroup":{"1":"Accesos adaptados","18":"Alquiler de bicicletas","10":"Animaci\u00f3n","17":"Business Center","13":"Cocina","2":"Consigna equipajes","12":"Gimnasio","11":"Habitaciones adaptadas","15":"Hidromasaje","4":"Internet","7":"Mascotas","9":"Minibar","3":"Parking","6":"Piscina","8":"Prensa","14":"Restaurante","5":"SPA","16":"Transfer"},"boards":{"TP":"Todo Incluido Premium","SA":"S\u00f3lo alojamiento","HD":"Desayuno","MP":"Media pensi\u00f3n","AL":"Almuerzo","MB":"Media Pensi\u00f3n Bebidas Incluidas","PC":"Pensi\u00f3n completa","TI":"Todo incluido","CE":"Cena","OT":"Otro r\u00e9gimen","FL":"Pensi\u00f3n completa plus: 15 restaurantes","HL":"Media pensi\u00f3n Plus: 15 restaurantes","HS":"Media pensi\u00f3n standard: 5 restaurantes","HR":"Media pensi\u00f3n premium: 20 restaurantes","FR":"Pensi\u00f3n completa premium: 20 restaurantes","FS":"Pensi\u00f3n completa standard: 5 restaurantes","HH":"Media pensi\u00f3n cena buffet en el hotel","FD":"Pensi\u00f3n completa comida en parque cena buffet hotel"},"categories":{"5E":"Hoteles 5 estrellas","4E":"Hoteles 4 estrellas","3E":"Hoteles 3 estrellas","2E":"Hoteles 2 estrellas","1E":"Hoteles 1 estrella","BB":"Bed\u0026 ...
# <script>!function(t){var e={};function n(o){if(e[o])return e[o].exports;var r=e[o]={i:o,l:!1,exports:{}};return t[o].call(r.exports,r,r.exports,n),r.l=!0,r.exports}n.m=t,n.c=e,n.d=function(t,e,o){n.o(t,e)||Object.defineProperty(t,e,{enumerable:!0,get:o})},n.r=function(t){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(t,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(t,"__esModule",{value:!0})},n.t=function(t,e){if(1&e&&(t=n(t)),8&e)return t;if(4&e&&"object"==typeof t&&t&&t.__esModule)return t;var o=Object.create(null);if(n.r(o),Object.defineProperty(o,"default",{enumerable:!0,value:t}),2&e&&"string"!=typeof t)for(var r in t)n.d(o,r,function(e){return t[e]}.bind(null,r));return o},n.n=function(t){var e=t&&t.__esModule?function(){return t.default}:function(){return t};return n.d(e,"a",e),e},n.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},n.p="/js_new/dist/",n(n.s=4034)}({210:function(t,e,n){"use strict";n.d(e,"a",(function(){return o})),n.d(e,"b",(function(){return i}));var o="viewCookieInfo";function r(t,e){return-1!==t.indexOf(e,t.length-e.length)}var i={areCookiesAccepted:function(){return!this.hostHasToAcceptCookies()||this.acceptedCookieExist()},navigatedFromSameHost:function(){return 0<=document.referrer.indexOf(window.location.host)},acceptedCookieExist:function(){return 0<=document.cookie.indexOf(o)},acceptedCoronavirusExist:function(){return 0<=document.cookie.indexOf("viewCoronavirusMessage")},hostHasToAcceptCookies:function(){return this.isAtrapalo()||this.isCatchit()||this.isCompany()},hostHasToAcceptCoronaVirusCookies:function(){return!1},isAtrapalo:function(){return r(window.location.host,"atrapalo.com")},isAtrapaloChile:function(){return r(window.location.host,"atrapalo.cl")},isAtrapaloPeru:function(){return r(window.location.host,"atrapalo.pe")},isAtrapaloArgentina:function(){return r(window.location.host,"atrapalo.com.ar")},isAtrapaloColombia:function(){return r(window.location.host,"atrapalo.com.co")},isCatchit:function(){return r(window.location.host,"catchit.com")},isCompany:function(){return r(window.location.host,"atrapaloempresas.com")}};e.c=i},4034:function(t,e,n){"use strict";n.r(e);var o=n(210),r=n(911);function i(){if(!window.tagManagerInitialized&&o.c.areCookiesAccepted()){window.tagManagerInitialized=!0;var t=Object(r.b)()?"GTM-NRTK83":"GTM-PDC59P";!function(t,e,n,o,r){t[o]=t[o]||[],t[o].push({"gtm.start":(new Date).getTime()});var i=e.getElementsByTagName(n)[0],a=e.createElement(n);a.async=!0,a.src="//www.googletagmanager.com/gtm.js?id="+r,i.parentNode.insertBefore(a,i)}(window,document,"script","dataLayer",t)}else window.dataLayer=window.dataLayer||[]}i(),e.default={init:i}},911:function(t,e,n){"use strict";n.d(e,"b",(function(){return o}));var o=function(){return-1<document.location.href.indexOf("www.dev.")};e.a={isDevel:o,isPreprod:function(){return(-1<document.location.href.indexOf("//pre")||-1<document.location.href.indexOf("//trunk"))&&-1<document.location.href.indexOf("www.dev.")}}}});</script>
# </body>
# </html>

# %%
span = []
for name in Pt:
    span.append(name.get_text().strip())

# %%
print(span)
# Out:
# ['', 'Si encuentras una oferta de hotel con un mejor precio en un plazo de 24h te devolvemos la diferencia (hasta un máximo de 100EUR).', 'Si encuentras una oferta de hotel con un mejor precio', 'te devolvemos la diferencia', 'Sólo tienes que enviarnos un email a mejorpreciogarantizadohot@atrapalo.com con la siguiente información:', 'Sólo tienes que enviarnos un email', 'con la siguiente información:', 'El sitio web donde lo has encontrado.', 'Un pantallazo de la oferta final (con tasas, gastos de gestión y cargos en la tarjeta) en el que conste también fecha y hora  de dicho pantallazo.', 'Tu nombre, dirección de correo electrónico y teléfono de contacto, junto con tu localizador de compra de Atrápalo.', 'Tras verificar los datos, te devolveremos el importe a través de un Vale Atrápalo El Vale será por reserva, válido para efectuar compras en el producto de hoteles, con una validez de 3 meses.', 'Tras verificar los datos, te devolveremos el importe a través de un Vale Atrápalo', 'La oferta encontrada tiene que tener las mismas características (mismas fechas, mismo hotel, mismo número de huéspedes, mismo tipo de habitación, condiciones de cancelación y misma forma de pago) y la diferencia debe ser de al menos 5 euros.', 'La oferta encontrada tiene que tener las mismas características', 'y la diferencia debe ser de al menos 5 euros.', 'El mejor precio garantizado de Atrápalo es aplicable sólo para compras realizadas en España y agencias minoristas.', 'Sólo está sujeto a tarifas especiales disponibles para el público general. Quedan excluidas tarifas especiales tipo: tarifas con acuerdo corporativos, para jóvenes, para agentes de viaje, para grupos, para diplomáticos o tarifas mayorista.', 'No se aplica a reservas canceladas ni a reservas que el proveedor del servicio no haya publicado o divulgado en el momento de la venta. Si recibimos la devolución del pago de tu reserva, el Vale de Atrápalo será anulado, como es lógico.', 'Si encuentras una oferta de hotel con un mejor precio en un plazo de 24h te devolvemos la diferencia (hasta un máximo de 100EUR).', 'Si encuentras una oferta de hotel con un mejor precio', 'te devolvemos la diferencia', 'Sólo tienes que enviarnos un email a mejorpreciogarantizadohot@atrapalo.com con la siguiente información:', 'Sólo tienes que enviarnos un email', 'con la siguiente información:', 'El sitio web donde lo has encontrado.', 'Un pantallazo de la oferta final (con tasas, gastos de gestión y cargos en la tarjeta) en el que conste también fecha y hora  de dicho pantallazo.', 'Tu nombre, dirección de correo electrónico y teléfono de contacto, junto con tu localizador de compra de Atrápalo.', 'Tras verificar los datos, te devolveremos el importe a través de un Vale Atrápalo El Vale será por reserva, válido para efectuar compras en el producto de hoteles, con una validez de 3 meses.', 'Tras verificar los datos, te devolveremos el importe a través de un Vale Atrápalo', 'La oferta encontrada tiene que tener las mismas características (mismas fechas, mismo hotel, mismo número de huéspedes, mismo tipo de habitación, condiciones de cancelación y misma forma de pago) y la diferencia debe ser de al menos 5 euros.', 'La oferta encontrada tiene que tener las mismas características', 'y la diferencia debe ser de al menos 5 euros.', 'El mejor precio garantizado de Atrápalo es aplicable sólo para compras realizadas en España y agencias minoristas.', 'Sólo está sujeto a tarifas especiales disponibles para el público general. Quedan excluidas tarifas especiales tipo: tarifas con acuerdo corporativos, para jóvenes, para agentes de viaje, para grupos, para diplomáticos o tarifas mayorista.', 'No se aplica a reservas canceladas ni a reservas que el proveedor del servicio no haya publicado o divulgado en el momento de la venta. Si recibimos la devolución del pago de tu reserva, el Vale de Atrápalo será anulado, como es lógico.', 'Publicidad', 'Publicidad', 'Publicidad', '', '', '', '', '', '', '', '', '933 197 570', '9 ...

# %%
Pt = soup.find_all('header')
print(Pt)
# Out:
# [<header class="header-section header-container__headerSection__3834172512 false"><a class="logo-atrapalo logo__logoSection__3834172512 logo__searchIsNotOpen__3834172512" href="https://www.atrapalo.com/" title="atrapalo.com - Ocio al mejor precio"><img alt="atrapalo.com - Ocio al mejor precio" class="atrapalo-text logo__fullLogo__3834172512" src="https://cdn.atrapalo.com/assets/common/brand-logo-negative.svg"/><img alt="atrapalo.com - Ocio al mejor precio" class="atrapalo-text logo__atrapador__3834172512" src="https://cdn.atrapalo.com/assets/common/brand-atrapador-negative.svg"/></a><nav class="column menu__columnSearchIsNotOpen__3834172512 menu__menuWrapper__3834172512"><div class="menu__expandable__3834172512 menu__onMediumUpFlex__3834172512"> <section class="menu__productSection__3834172512"><a class="menu__productLink__3834172512" href="https://www.atrapalo.com/hoteles/"><div class="menu__productText__3834172512">Hoteles</div></a><div class="menu__moreSection__3834172512"><div class="menu__moreText__3834172512">Más</div><i class="menu__arrowDown__3834172512 menu__arrowClose__3834172512"></i></div></section><div class="menu__backdrop__3834172512 menu__displayNone__3834172512" style="top:62px"><div class="menu__menuContainer__3834172512 menu__displayNone__3834172512 menu__withColumnContainer__3834172512" style="left:0px"><ul class="menu__menuLinks__3834172512 menu__withColumn__3834172512"><li class="product menu-item__product__3834172512 column menu-item__productColumn__3834172512 menu-item__productColumnNoActive__3834172512"><a class="menu-item__productLink__3834172512" href="https://www.atrapalo.com/entradas/" title="Entradas"><svg class="icon" height="20px" role="img" viewbox="0 0 32 32" width="20px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><path d="M20.295 2.263l3.97.002a1 1 0 011 1v26a1 1 0 01-1 1h-3.97c-.53 0-.53-.373-.53-.565a3.5 3.5 0 10-7 0c0 .192 0 .565-.487.565H8.264a1 1 0 01-1-1v-26a1 1 0 011-1l4.014-.002c.486 0 .486.374.486.567a3.5 3.5 0 007 0c0-.567.531-.565.531-.567zm1.278 2l-.015.063a5.502 5.502 0 01-10.588 0l-.017-.062h-1.69v24h1.69l.017-.06a5.503 5.503 0 015.073-4l.221-.004a5.502 5.502 0 015.294 4.004l.015.06h1.69v-24h-1.69z" id="shows_svg__a"></path></defs><use fill="currentColor" fill-rule="nonzero" transform="rotate(45 16.264 16.264)" xlink:href="#shows_svg__a"></use></svg><div class="menu-item__productText__3834172512 menu-item__productTextFontSizeColumn__3834172512">Entradas</div></a></li><li class="product menu-item__product__3834172512 column menu-item__productColumn__3834172512 menu-item__productColumnNoActive__3834172512"><a class="menu-item__productLink__3834172512" href="https://www.atrapalo.com/actividades/" title="Actividades"><svg class="icon" height="20px" role="img" viewbox="0 0 32 32" width="20px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><path d="M23.355 18.887c1.673-2.63 2.704-5.786 2.704-8.31 0-5.288-4.6-9.59-10.254-9.59S5.55 5.289 5.55 10.577c0 2.525 1.031 5.681 2.704 8.311l-.006.004 3.975 6.889a1.902 1.902 0 00-.139.716v2.571c0 1.068.879 1.937 1.96 1.937h3.52c1.081 0 1.96-.869 1.96-1.937v-2.571c0-.248-.047-.488-.139-.716l3.976-6.891-.007-.004.001.001zm-9.43 7.61c0-.063.054-.114.12-.114h3.52c.066 0 .119.051.119.114v2.571a.117.117 0 01-.119.114h-3.52a.117.117 0 01-.12-.114v-2.571zm3.64-1.937h-3.52c-.129 0-.258.013-.384.038l-.685-1.188c.929.44 1.877.663 2.83.663.953 0 1.901-.223 2.83-.663l-.686 1.189a1.976 1.976 0 00-.384-.038l-.001-.001zm1.011-3.211c.386-.739.748-1.659 1.079-2.749.771-2.533 1.269-5.75 1.269-8.194 0-2.409-.47-4.688-1.324-6.417a9.583 9.583 0 00-.239-.452c2.939 1.266 4.856 3.997 4.856 7.038 0 2.245-1.014 5.223-2.583 7.589-.824 1.242-1.771 2.267-2.739 2.966a7.873 7.873 0 01-.32.218l.001.001zm-.682-3.274c-.374 1.23-.8 2.238-1.233 2.917-.424.665-.745.841-.856.841-.111 0-.433-.176-.857-.841-.432-.679-.858-1.688-1.232-2.917-.723-2.376-1.191-5.386-1.191-7.668 0-2.137.404-4.131 1.137-5.616.612-1.2 ...
# <a class="btnModal" href="#" id="js_btn_acces_cancelar" title="">Cancelar</a>
# <span>Iniciar sesión</span>
# </header>]

# %%
import urllib.request

datos = urllib.request.urlopen("https://www.atrapalo.com/hoteles/results/e27cc366501427ea755a61f72a8274ca/1:0:0:0:97134/").read().decode()
soup =  BeautifulSoup(datos)
tags = soup("a")
for tag in tags:
    print(tag.get("href"))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-20-291202641204> in <module>
#       1 import urllib.request
#       2
# ----> 3 datos = urllib.request.urlopen("https://www.atrapalo.com/hoteles/results/e27cc366501427ea755a61f72a8274ca/1:0:0:0:97134/").read().decode('utf-8')
#       4 soup =  BeautifulSoup(datos)
#       5 tags = soup("a")
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe1 in position 62: invalid continuation byte

# %% [markdown]
# class ExpeHotelScraper:
#
#
#     def __init__(self, url):
#
#        self.url = url
#
#        self.download_page()
#
#
#     def download_page(self):
#
#        # method for downloading the hotel page
#
#        self.page = requests.get(self.url).text
#
#
#     def scrape_data(self):
#
#        #method for scraping out hotel name, address, and about
#
#        soup = BeautifulSoup(self.page, "html.parser")
#
#        hotel_name = soup.find("h1", {"class": "uitk-heading-3"}).text
#
#        hotel_address = soup.find("div", {"data-stid": "content-hotel-address"}).text
#
#        hotel_about = soup.find("div", {"data-stid": "content-markup"}).text
#
#        return {"name": hotel_name,
#
#                "about": hotel_about,
#
#                "address": hotel_address
#
#                }
#
#
#
# urls = ["https://www.expedia.com/California-Hotels-Holiday-Inn-Express-Suites-Lexington-Park-California.h9741955.Hotel-Information?chkin=2021-10-17&chkout=2021-10-18&x_pwa=1&rfrr=HSR&pwa_ts=1633296934579&referrerUrl=aHR0cHM6Ly93d3cuZXhwZWRpYS5jb20vSG90ZWwtU2VhcmNo&useRewards=false&rm1=a2®ionId=85533&destination=California%2C+Maryland%2C+United+States+of+America&destType=MARKET&sort=RECOMMENDED&top_dp=123&top_cur=USD&semdtl=&userIntent=&selectedRoomType=201330831&selectedRatePlan=380921932",]
# for url in urls:
#     x = ExpeHotelScraper(url)
#
#     print(x.scrape_data())

# %% [markdown]
# class ExpeHotelScraper:
#     def __init__(self, url):
#         self.url = url
#         self.download_page()
#
#     def download_page(self):
#         # method for downloading the hotel page
#         self.page = requests.get(self.url).text
#
#     def scrape_data(self):
#         #method for scraping out hotel name, address, and about
#         soup = BeautifulSoup(self.page, "html.parser")
#         hotel_name = soup.find("h1", {"class": "uitk-heading-3"}).text
#         hotel_address = soup.find("div", {"data-stid": "content-hotel-address"}).text
#         hotel_about = soup.find("div", {"data-stid": "content-markup"}).text
#         return {"name": hotel_name,“about”: hotel_about, “address”: hotel_address}
#
# urls = [“https://www.expedia.com/California-Hotels-Holiday-Inn-Express-Suites-Lexington-Park-California.h9741955.Hotel-Information?chkin=2021-10-17&chkout=2021-10-18&x_pwa=1&rfrr=HSR&pwa_ts=1633296934579&referrerUrl=aHR0cHM6Ly93d3cuZXhwZWRpYS5jb20vSG90ZWwtU2VhcmNo&useRewards=false&rm1=a2&regionId=85533&destination=California%2C+Maryland%2C+United+States+of+America&destType=MARKET&sort=RECOMMENDED&top_dp=123&top_cur=USD&semdtl=&userIntent=&selectedRoomType=201330831&selectedRatePlan=380921932”,]
#
# for url in urls:
#
#     x = ExpeHotelScraper(url)
#
#     print(x.scrape_data())
